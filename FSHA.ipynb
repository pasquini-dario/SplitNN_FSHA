# %% [markdown]
# # Load datasets

# %%
import tensorflow as tf
import numpy as np
import tqdm
import matplotlib.pyplot as plt

import styleloss
import FSHA
import architectures
import datasets
from datasets import *

xpriv, xpub = load_mnist()

n = 15
x_priv = datasets.getImagesDS(xpriv, n)
x_pub = datasets.getImagesDS(xpub, n)

datasets.plot(x_priv)
datasets.plot(x_pub)

# %% [markdown]
# # Setup attack:

# %%
batch_size = 64
id_setup = 2
hparams = {
    'WGAN' : True,
    'gradient_penalty' : 500.,
    'style_loss' : None,
    'lr_f' :  0.00001,
    'lr_tilde' : 0.00001,
    'lr_D' : 0.0001,
}

fsha = FSHA.FSHA(xpriv, xpub, id_setup, batch_size, hparams)

# %% [markdown]
# # Run attack:

# %%
log_frequency = 50
LOG = fsha(5000, verbose=True, progress_bar=False, log_frequency=log_frequency)
# Out:
# RUNNING...
# Use WGAN loss
# Use GP
# Use WGAN loss
# Use GP
# log--00%-0000000] validation: 0.8812
# log--01%-0000050] validation: 0.8776
# log--02%-0000100] validation: 0.8679
# log--03%-0000150] validation: 0.7160
# log--04%-0000200] validation: 0.5075
# log--05%-0000250] validation: 0.4230
# log--06%-0000300] validation: 0.3593
# log--07%-0000350] validation: 0.3153
# log--08%-0000400] validation: 0.2796
# log--09%-0000450] validation: 0.2609
# log--10%-0000500] validation: 0.2439
# log--11%-0000550] validation: 0.2383
# log--12%-0000600] validation: 0.2244
# log--13%-0000650] validation: 0.2152
# log--14%-0000700] validation: 0.2131
# log--15%-0000750] validation: 0.2061
# log--16%-0000800] validation: 0.2021
# log--17%-0000850] validation: 0.1974
# log--18%-0000900] validation: 0.1902
# log--19%-0000950] validation: 0.1854
# log--20%-0001000] validation: 0.1845
# log--21%-0001050] validation: 0.1788
# log--22%-0001100] validation: 0.1888
# log--23%-0001150] validation: 0.1742
# log--24%-0001200] validation: 0.1913
# log--25%-0001250] validation: 0.1715
# log--26%-0001300] validation: 0.1646
# log--27%-0001350] validation: 0.1759
# log--28%-0001400] validation: 0.1688
# log--28%-0001450] validation: 0.1646
# log--30%-0001500] validation: 0.1530
# log--31%-0001550] validation: 0.1585
# log--32%-0001600] validation: 0.1533
# log--33%-0001650] validation: 0.1448
# log--34%-0001700] validation: 0.1421
# log--35%-0001750] validation: 0.1342
# log--36%-0001800] validation: 0.1363
# log--37%-0001850] validation: 0.1304
# log--38%-0001900] validation: 0.1283
# log--39%-0001950] validation: 0.1205
# log--40%-0002000] validation: 0.1185
# log--41%-0002050] validation: 0.1190
# log--42%-0002100] validation: 0.1168
# log--43%-0002150] validation: 0.1100
# log--44%-0002200] validation: 0.1136
# log--45%-0002250] validation: 0.1146
# log--46%-0002300] validation: 0.1063
# log--47%-0002350] validation: 0.1012
# log--48%-0002400] validation: 0.1073
# log--49%-0002450] validation: 0.1056
# log--50%-0002500] validation: 0.1027
# log--51%-0002550] validation: 0.0982
# log--52%-0002600] validation: 0.1002
# log--53%-0002650] validation: 0.0990
# log--54%-0002700] validation: 0.0953
# log--55%-0002750] validation: 0.0931
# log--56%-0002800] validation: 0.0975
# log--56%-0002850] validation: 0.0956
# log--57%-0002900] validation: 0.0905
# log--59%-0002950] validation: 0.0911
# log--60%-0003000] validation: 0.0897
# log--61%-0003050] validation: 0.0890
# log--62%-0003100] validation: 0.0899
# log--63%-0003150] validation: 0.0846
# log--64%-0003200] validation: 0.0900
# log--65%-0003250] validation: 0.0855
# log--66%-0003300] validation: 0.0851
# log--67%-0003350] validation: 0.0854
# log--68%-0003400] validation: 0.0887
# log--69%-0003450] validation: 0.0839
# log--70%-0003500] validation: 0.0774
# log--71%-0003550] validation: 0.0780
# log--72%-0003600] validation: 0.0853
# log--73%-0003650] validation: 0.0797
# log--74%-0003700] validation: 0.0733
# log--75%-0003750] validation: 0.0807
# log--76%-0003800] validation: 0.0784
# log--77%-0003850] validation: 0.0717
# log--78%-0003900] validation: 0.0698
# log--79%-0003950] validation: 0.0727
# log--80%-0004000] validation: 0.0753
# log--81%-0004050] validation: 0.0705
# log--82%-0004100] validation: 0.0686
# log--83%-0004150] validation: 0.0685
# log--84%-0004200] validation: 0.0822
# log--85%-0004250] validation: 0.0705
# log--86%-0004300] validation: 0.0645
# log--87%-0004350] validation: 0.0643
# log--88%-0004400] validation: 0.0687
# log--89%-0004450] validation: 0.0705
# log--90%-0004500] validation: 0.0647
# log--91%-0004550] validation: 0.0616
# log--92%-0004600] validation: 0.0679
# log--93%-0004650] validation: 0.0683
# log--94%-0004700] validation: 0.0610
# log--95%-0004750] validation: 0.0611
# log--96%-0004800] validation: 0.0631
# log--97%-0004850] validation: 0.0623
# log--98%-0004900] validation: 0.0583
# log--99%-0004950] validation: 0.0649

# %% [markdown]
# # Plot logs:

# %%
def plot_log(ax, x, y, label):
    ax.plot(x, y, color='black')
    ax.set(title=label)
    ax.grid()

if hparams.get('style_loss'):
    n = 5
else:
    n = 4
fix, ax = plt.subplots(1, n, figsize=(n*5, 3))
x = np.arange(0, len(LOG)) * log_frequency 

plot_log(ax[0], x, LOG[:, 0], label='Loss $f$')
plot_log(ax[1], x, LOG[:, 1],  label='Loss $\\tilde{f}$ and $\\tilde{f}^{-1}$')
plot_log(ax[2], x, LOG[:, 2],  label='Loss $D$')
plot_log(ax[3], x, LOG[:, 3],  label='Reconstruction error (VALIDATION)')

ax[2].plot(LOG[:, 3], label='validation')
if hparams.get('style_loss'):
    plot_log(ax[4], x, LOG[:, 4], label='style loss')

# %% [markdown]
# # Plot reconstruction private data:

# %%
n = 20
X = getImagesDS(xpriv, n)
X_recovered, control = fsha.attack(X)

def plot(X):
    n = len(X)
    X = (X+1)/2
    fig, ax = plt.subplots(1, n, figsize=(n*3,3))
    plt.axis('off')
    plt.subplots_adjust(wspace=0, hspace=-.05)
    for i in range(n):
        ax[i].imshow((X[i]), cmap='inferno');  
        ax[i].set(xticks=[], yticks=[])
        ax[i].set_aspect('equal')
        
    return fig


fig = plot(X)
fig = plot(X_recovered)
